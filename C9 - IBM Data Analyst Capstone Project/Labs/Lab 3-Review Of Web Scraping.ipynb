# %% [markdown]
# # **Web Scraping Lab**

# %% [markdown]
# ## Objectives

# %% [markdown]
# After completing this lab, you will be able to:

# %% [markdown]
# * Download a webpage using requests module
# * Scrape all links from a webpage
# * Scrape all image URLs from a web page
# * Scrape data from html tables

# %% [markdown]
# ## Scrape www.ibm.com

# %% [markdown]
# Import the required modules and functions

# %%
from bs4 import BeautifulSoup # this module helps in web scrapping.
import requests  # this module helps us to download a webpage

# %% [markdown]
# Download the contents of the webpage

# %%
url = "http://www.ibm.com"

# %%
# get the contents of the webpage in text format and store in a variable called data
data  = requests.get(url).text

# %% [markdown]
# Create a soup object using the class BeautifulSoup

# %%
soup = BeautifulSoup(data,"html.parser")  # create a soup object using the variable 'data'

# %% [markdown]
# Scrape all links

# %%
for link in soup.find_all('a'):  # in html anchor/link is represented by the tag <a>
    print(link.get('href'))
# Out:
# https://www.ibm.com/products/ai-coding-agent?lnk=hpls1in
# https://bob.ibm.com/trial
# https://bob.ibm.com/?lnk=hprc1in
# https://www.ibm.com/events/reg/flow/ibm/dmtiv3mb/landing/page/landing?lnk=hprc2in
# https://www.ibm.com/products/maximo?lnk=hprc3in
# 1_zznbl4r6
# https://www.ibm.com/forms/webinars/mkt-webinar-209cb?utm_medium=Organic&utm_source=web
# https://www.ibm.com/new/announcements/shifting-from-ai-assisted-coding-to-ai-assisted-delivery-with-ibm-bob?lnk=hpthanau2
# https://www.ibm.com/new/announcements/from-insight-to-action-closing-the-gap-in-modern-it-operations?lnk=hpthanau4
# https://www.ibm.com/new/announcements/ibm-data-gate-for-confluent-turning-z-data-into-real-time-action?lnk=hpthanau3
# https://www.ibm.com/new/announcements/ibm-sovereign-core-the-new-end-to-end-system-for-sovereign-ai?lnk=hpthanau5
# https://www.ibm.com/sports/ferrari
# https://www.ibm.com/case-studies/avid-solutions-international?lnk=hpcs2au
# https://www.ibm.com/case-studies/pfizer?lnk=hpcs3au
# https://www.ibm.com/case-studies/us-open?lnk=hpcs4au
# https://www.ibm.com/forms/mkt-webinar-17722?utm_source=ibmcom&utm_medium=web
# https://www.ibm.com/events/techxchange?lnk=hpdev1in
# https://github.com/ibm-granite-community/granite-snack-cookbook?lnk=hpdev2us
# https://developer.ibm.com/technologies/artificial-intelligence/?lnk=hpdev3us
# https://www.ibm.com/forms/mkt-51898?lnk=hpdev4in
# https://www.ibm.com/products/watsonx-orchestrate?lnk=hpdev5in
# https://research.ibm.com/blog/granite-vision-ocr-leaderboard?lnk=hpdev6us
# https://www.ibm.com/new/announcements/governing-ai-with-confidence-our-journey-with-watsonx-governance?lnk=hpdev7us
# https://www.ibm.com/products/maximo?lnk=hpdev8in
# https://www.ibm.com/software?lnk=hpfp1in
# https://www.ibm.com/solutions/ai-agents?lnk=hpfp2in
# https://www.ibm.com/solutions/data-and-ai?lnk=hpfp3in
# https://www.ibm.com/solutions/automation?lnk=hpfp4in
# https://www.ibm.com/solutions/hybrid-cloud?lnk=hpfp5in
# https://www.ibm.com/solutions/ai-models?lnk=hpfp6in
# https://www.ibm.com/solutions/analytics?lnk=hpfp7in
# https://www.ibm.com/solutions/security?lnk=hpfp8in
# https://www.ibm.com/consulting?lnk=hpfp9in
# None
# https://www.ibm.com/in-en/about?lnk=hpii1in
# https://www.ibm.com/events/think/mumbai?lnk=hpii1in
# https://research.ibm.com?lnk=hpii1in
# https://www.ibm.com/quantum?lnk=hpii1in
# https://www.ibm.com/in-en/careers?lnk=hpii1in
# https://skillsbuild.org?lnk=hpii1in
# https://in.newsroom.ibm.com/2025-12-19-IBM-commits-to-skill-5-million-Indian-youth-in-AI,-Cybersecurity-Quantum-by-2030
# https://in.newsroom.ibm.com/2025-12-02-Karnataka-Bank-Innovates-with-IBM-to-Build-Future-Ready-API-Platform
# https://in.newsroom.ibm.com/AI-To-Power-India-Next-Economic-Leap
# https://in.newsroom.ibm.com/IBM-Yotta-Announce-Plans-Agentic-AI-Platform
# https://in.newsroom.ibm.com/Tata-Play-Fiber-IBM-Build-AI-Ready-Data-Infrastructure
# https://in.newsroom.ibm.com/IBM-Launches-Its-First-Infrastructure-Innovation-Center-in-India-to-Accelerate-Enterprise-Scale-AI
# https://in.newsroom.ibm.com/IBM-Launches-AI-GovTech-Innovation-Center
# https://in.newsroom.ibm.com/2026-02-20-Government-of-Andhra-Pradesh-collaborates-with-IBM-BharatGen-NxtGen-to-scale-impact-from-India-AI

# %% [markdown]
# Scrape  all images

# %%
for link in soup.find_all('img'):# in html image is represented by the tag <img>
    print(link.get('src'))
# Out:
# https://assets.ibm.com/is/image/ibm/2025_wxo_sizzle_orchestrate_partner_scene01?ts=1778504113794&dpr=off
# https://assets.ibm.com/is/image/ibm/bob?ts=1777983270274&dpr=off
# https://assets.ibm.com/is/image/ibm/5b99e3bb-5f53-4849-879188254a121189?ts=1779190498336&dpr=off
# https://assets.ibm.com/is/image/ibm/ibm_illo_col_sustainability_product_maximo_all_v_1_0_mobile-device-management?ts=1777033263827&dpr=off
# https://assets.ibm.com/is/image/ibm/ibm_sovereigncore_teams_background_02?ts=1777983255306&dpr=off
# https://assets.ibm.com/is/image/ibm/webmethods-unified-experience?ts=1779190603421&dpr=off
# https://assets.ibm.com/is/image/ibm/ibm_think_layersb_editorial_still_4k?ts=1778061059105&dpr=off
# https://assets.ibm.com/is/image/ibm/bob-imagery-3200x1280?ts=1778006099192&dpr=off
# https://assets.ibm.com/is/image/ibm/ferrari-shield-transparent?ts=1775571364568&dpr=off
# https://assets.ibm.com/is/content/ibm/avidsolutions?ts=1771506986272&dpr=off
# https://assets.ibm.com/is/image/ibm/pfizer_logo-1?ts=1771506992781&dpr=off
# https://assets.ibm.com/is/image/ibm/us-open-logo-2-1?ts=1775571544839&dpr=off
# https://assets.ibm.com/is/image/ibm/f678_still_f06_v10_zyn_4096x4096?ts=1775559808648&dpr=off
# https://assets.ibm.com/is/image/ibm/avid-solutions-leadspace?ts=1769516746856&dpr=off
# https://assets.ibm.com/is/image/ibm/pfizer_thumb?ts=1771507043984&dpr=off
# https://assets.ibm.com/is/image/ibm/ashe-day-1-dustin-satloff_usta-2500pxw?ts=1771507087706&dpr=off
# https://assets.ibm.com/is/image/ibm/b1608778-54c5-4db5-bb964e79fbc26573?ts=1778504037490&dpr=off
# https://assets.ibm.com/is/image/ibm/watson-discovery_eye-connection_1x1_padding?ts=1758831124391&dpr=off

# %% [markdown]
# ## Scrape data from html tables

# %%
#The below URL contains a html table with data about colors and color codes.
URL = "https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DA0321EN-SkillsNetwork/labs/datasets/HTMLColorCodes.html"

# %% [markdown]
# Before proceeding to scrape a website, you need to examine the contents, and the way data is organized on the website. Open the above URL in your browser and check how many rows and columns are there in the color table.

# %%
# get the contents of the webpage in text format and store in a variable called data
data  = requests.get(URL).text

# %%
soup = BeautifulSoup(data,"html.parser")

# %%
#find a html table in the web page
table = soup.find('table') # in html table is represented by the tag <table>

# %% [markdown]
# # Get all rows from the table

# %%
for row in table.find_all('tr'): # in html table row is represented by the tag <tr>
    # Get all columns in each row.
    cols = row.find_all('td') # in html a column is represented by the tag <td>
    color_name = cols[2].getText() # store the value in column 3 as color_name
    color_code = cols[3].getText() # store the value in column 4 as color_code
    print("{}--->{}".format(color_name,color_code))
# Out:
# Color Name--->Hex Code#RRGGBB
# lightsalmon--->#FFA07A
# salmon--->#FA8072
# darksalmon--->#E9967A
# lightcoral--->#F08080
# coral--->#FF7F50
# tomato--->#FF6347
# orangered--->#FF4500
# gold--->#FFD700
# orange--->#FFA500
# darkorange--->#FF8C00
# lightyellow--->#FFFFE0
# lemonchiffon--->#FFFACD
# papayawhip--->#FFEFD5
# moccasin--->#FFE4B5
# peachpuff--->#FFDAB9
# palegoldenrod--->#EEE8AA
# khaki--->#F0E68C
# darkkhaki--->#BDB76B
# yellow--->#FFFF00
# lawngreen--->#7CFC00
# chartreuse--->#7FFF00
# limegreen--->#32CD32
# lime--->#00FF00
# forestgreen--->#228B22
# green--->#008000
# powderblue--->#B0E0E6
# lightblue--->#ADD8E6
# lightskyblue--->#87CEFA
# skyblue--->#87CEEB
# deepskyblue--->#00BFFF
# lightsteelblue--->#B0C4DE
# dodgerblue--->#1E90FF
